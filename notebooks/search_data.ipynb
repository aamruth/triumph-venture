# %%
import pandas as pd

# %%
data = pd.read_csv('../data/Startup-newdata/companies.csv', encoding="utf-8", encoding_errors= 'replace')

# %%
data.head(10)
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
# 5     /organization/01games-technology      01Games Technology
# 6  /organization/0ndine-biomedical-inc  Ondine Biomedical Inc.
# 7                 /organization/0xdata                  H2O.ai
# 8                      /organization/1                One Inc.
# 9            /organization/1-2-3-listo             1,2,3 Listo
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
# 5             http://www.01games.hk/
# 6               http://ondinebio.com
# 7                     http://h2o.ai/
# 8                 http://whatis1.com
# 9            http://www.123listo.com
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
# 5                                              Games             41250
# 6                                      Biotechnology            762851
# 7                                          Analytics          33600000
# 8                                             Mobile           1150050
# 9                                         E-Commerce             40000
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
# 5  operating          HKG        NaN              Hong Kong      Hong Kong
# 6  operating          CAN         BC              Vancouver      Vancouver
# 7  operating          USA         CA            SF Bay Area  Mountain View
# 8  operating          USA         CA            SF Bay Area  San Francisco
# 9  operating          CHL         12               Santiago     Las Condes
#
#    funding_rounds  founded_at first_funding_at last_funding_at
# 0               1         NaN       2015-01-05      2015-01-05
# 1               2  2014-09-04       2014-03-01      2014-10-14
# 2               1         NaN       2014-01-30      2014-01-30
# 3               1  2007-01-01       2008-03-19      2008-03-19
# 4               1  2010-01-01       2014-07-24      2014-07-24
# 5               1         NaN       2014-07-01      2014-07-01
# 6               2  1997-01-01       2009-09-11      2009-12-21
# 7               4  2011-01-01       2013-01-03      2015-11-09
# 8               3  2011-08-01       2011-07-20      2014-02-05
# 9               1  2012-01-01       2013-02-18      2013-02-18

# %%
data2 = pd.read_csv('../data/Startup-newdata/rounds.csv', encoding="utf-8", encoding_errors= 'replace')

# %%
data2.head()
# Out:
#                      company_permalink            company_name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2               /organization/-qounter                :Qounter
# 3  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 4                /organization/0-6-com                 0-6.com
#
#                                company_category_list company_country_code  \
# 0                                              Media                  IND
# 1  Application Platforms|Real Time|Social Network...                  USA
# 2  Application Platforms|Real Time|Social Network...                  USA
# 3                                  Apps|Games|Mobile                  NaN
# 4                                        Curated Web                  CHN
#
#   company_state_code company_region   company_city  \
# 0                 16         Mumbai         Mumbai
# 1                 DE     DE - Other  Delaware City
# 2                 DE     DE - Other  Delaware City
# 3                NaN            NaN            NaN
# 4                 22        Beijing        Beijing
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  2015-01-05         10000000.0
# 1                  A  2014-10-14                NaN
# 2                NaN  2014-03-01           700000.0
# 3                  B  2014-01-30          3406878.0
# 4                  A  2008-03-19          2000000.0

# %%
data[data["name"] == "JagTag"]
# Out:
#                   permalink    name           homepage_url category_list  \
# 29382  /organization/jagtag  JagTag  http://www.jagtag.com        Mobile
#
#       funding_total_usd    status country_code state_code  region       city  \
# 29382           3628372  acquired          USA         NJ  Newark  Princeton
#
#        funding_rounds  founded_at first_funding_at last_funding_at
# 29382               1  2007-01-01       2009-12-17      2009-12-17

# %%
data2[data2["company_name"] == ":Qounter"]
# Out:
#         company_permalink company_name  \
# 1  /organization/-qounter     :Qounter
# 2  /organization/-qounter     :Qounter
#
#                                company_category_list company_country_code  \
# 1  Application Platforms|Real Time|Social Network...                  USA
# 2  Application Platforms|Real Time|Social Network...                  USA
#
#   company_state_code company_region   company_city  \
# 1                 DE     DE - Other  Delaware City
# 2                 DE     DE - Other  Delaware City
#
#                            funding_round_permalink funding_round_type  \
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
#
#   funding_round_code   funded_at  raised_amount_usd
# 1                  A  2014-10-14                NaN
# 2                NaN  2014-03-01           700000.0

# %%
data3 = pd.read_csv('./clean_search.csv', encoding="utf-8", encoding_errors= 'replace')

# %%
data3.head(20)
# Out:
#                   name  funding_total_usd     status country_code  \
# 0             #waywire            1750000   acquired          USA
# 1   &TV Communications            4000000  operating          USA
# 2    'Rock' Your Paper              40000  operating        Other
# 3    (In)Touch Network            1500000  operating        Other
# 4   -R- Ranch and Mine              60000  operating          USA
# 5        .Fox Networks            4912393     closed        Other
# 6              0-6.com            2000000  operating        Other
# 7   01Games Technology              41250  operating        Other
# 8          1,2,3 Listo              40000  operating        Other
# 9      10 Minutes With            4400000  operating        Other
# 10         10-20 Media            2050000  operating          USA
# 11          1000 Corks              40000  operating          USA
# 12        1000 Markets             500000   acquired        Other
# 13        1000memories            2535000   acquired          USA
# 14     1000museums.com            4962651  operating          USA
# 15          1001 Menus            4059079  operating        Other
# 16             1006.tv           10000000  operating        Other
# 17            100du.tv            3000000  operating        Other
# 18            100e.com            4500000  operating        Other
# 19           100health             420000  operating          USA
#
#     funding_rounds           Industry_Group  time_between_first_last_funding  \
# 0                1   Content and Publishing                                0
# 1                2                   Gaming                              111
# 2                1   Content and Publishing                                0
# 3                1     Consumer Electronics                                0
# 4                2       Travel and Tourism                               40
# 5                1              Advertising                                0
# 6                1        Internet Services                                0
# 7                1                   Gaming                                0
# 8                1    Commerce and Shopping                                0
# 9                2                Education                              646
# 10               4    Commerce and Shopping                              923
# 11               1        Internet Services                                0
# 12               1    Commerce and Shopping                                0
# 13               2        Internet Services                              411
# 14               6        Internet Services                             1801
# 15               4        Food and Beverage                              333
# 16               3  Media and Entertainment                             1307
# 17               2              Health Care                              949
# 18               2                Education                              243
# 19               1              Health Care                                0
#
#     days_in_business
# 0               1307
# 1               2035
# 2               1160
# 3               1734
# 4                728
# 5               3270
# 6               3285
# 7                547
# 8               1459
# 9               1093
# 10              5476
# 11              2920
# 12              2554
# 13              2008
# 14              2920
# 15              1866
# 16              2554
# 17              2914
# 18              3650
# 19               544

# %%
company = data3[data3["name"] == "1006.tv"].iloc[0]

# %%
company["status"]
# Out:
# 'operating'
